# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Memuna Javed\OneDrive\Documents\Data Science\Projects\NASA's_airfoil_selfnoise\AirfoilSelfNoise.csv")
df.head()
# Out:
#       f  alpha       c  U_infinity     delta     SSPL
# 0   800    0.0  0.3048        71.3  0.002663  126.201
# 1  1000    0.0  0.3048        71.3  0.002663  125.201
# 2  1250    0.0  0.3048        71.3  0.002663  125.951
# 3  1600    0.0  0.3048        71.3  0.002663  127.591
# 4  2000    0.0  0.3048        71.3  0.002663  127.461

# %%
df.columns=['Frequency','Angle','Chord Length','Speed of Air','Displacement','Sound Pressure']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1503 entries, 0 to 1502
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Frequency       1503 non-null   int64
#  1   Angle           1503 non-null   float64
#  2   Chord Length    1503 non-null   float64
#  3   Speed of Air    1503 non-null   float64
#  4   Displacement    1503 non-null   float64
#  5   Sound Pressure  1503 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 70.6 KB

# %%
df.describe()
# Out:
#           Frequency        Angle  Chord Length  Speed of Air  Displacement  \
# count   1503.000000  1503.000000   1503.000000   1503.000000   1503.000000
# mean    2886.380572     6.782302      0.136548     50.860745      0.011140
# std     3152.573137     5.918128      0.093541     15.572784      0.013150
# min      200.000000     0.000000      0.025400     31.700000      0.000401
# 25%      800.000000     2.000000      0.050800     39.600000      0.002535
# 50%     1600.000000     5.400000      0.101600     39.600000      0.004957
# 75%     4000.000000     9.900000      0.228600     71.300000      0.015576
# max    20000.000000    22.200000      0.304800     71.300000      0.058411
#
#        Sound Pressure
# count     1503.000000
# mean       124.835943
# std          6.898657
# min        103.380000
# 25%        120.191000
# 50%        125.721000
# 75%        129.995500
# max        140.987000

# %%
df
# Out:
#       Frequency  Angle  Chord Length  Speed of Air  Displacement  \
# 0           800    0.0        0.3048          71.3      0.002663
# 1          1000    0.0        0.3048          71.3      0.002663
# 2          1250    0.0        0.3048          71.3      0.002663
# 3          1600    0.0        0.3048          71.3      0.002663
# 4          2000    0.0        0.3048          71.3      0.002663
# ...         ...    ...           ...           ...           ...
# 1498       2500   15.6        0.1016          39.6      0.052849
# 1499       3150   15.6        0.1016          39.6      0.052849
# 1500       4000   15.6        0.1016          39.6      0.052849
# 1501       5000   15.6        0.1016          39.6      0.052849
# 1502       6300   15.6        0.1016          39.6      0.052849
#
#       Sound Pressure
# 0            126.201
# 1            125.201
# 2            125.951
# 3            127.591
# 4            127.461
# ...              ...
# 1498         110.264
# ...

# %%
x,y=df[['Frequency','Angle','Chord Length','Speed of Air','Displacement']],df['Sound Pressure']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=model.predict(x_test)

# %%
df2=pd.DataFrame({'Actual Answers':y_test,'Predicted Answers':y_predict,'Difference Percentage':((y_predict-y_test)/y_test)*100})

# %%
df2
# Out:
#       Actual Answers  Predicted Answers  Difference Percentage
# 91           117.741         119.610286               1.587625
# 75           118.122         119.909747               1.513475
# 1213         120.657         125.777508               4.243855
# 330          122.229         125.916354               3.016758
# 1352         129.343         130.648470               1.009308
# ...              ...                ...                    ...
# 1152         122.606         128.623050               4.907631
# 1131         123.537         128.323107               3.874230
# 12           112.241         112.691202               0.401103
# 408          136.284         125.130271              -8.184181
# 73           121.762         122.863874               0.904941
#
# [301 rows x 3 columns]

# %%
df2.describe()
# Out:
#        Actual Answers  Predicted Answers  Difference Percentage
# count      301.000000         301.000000             301.000000
# mean       124.769904         125.206656               0.493601
# std          6.528046           4.665465               3.875047
# min        107.147000         109.050989              -9.101263
# 25%        120.657000         122.624086              -2.052051
# 50%        125.499000         125.331553               0.144294
# 75%        129.965000         128.406594               2.688985
# max        138.758000         135.669497              13.820082

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_predict)

# %%
score*100
# Out:
# 45.648174114810935

# %%
df2['Residual']=y_test-y_predict
residual=y_test-y_predict

# %%
df2.drop('Difference Percentage', axis=1)
# Out:
#       Actual Answers  Predicted Answers   Residual
# 91           117.741         119.610286  -1.869286
# 75           118.122         119.909747  -1.787747
# 1213         120.657         125.777508  -5.120508
# 330          122.229         125.916354  -3.687354
# 1352         129.343         130.648470  -1.305470
# ...              ...                ...        ...
# 1152         122.606         128.623050  -6.017050
# 1131         123.537         128.323107  -4.786107
# 12           112.241         112.691202  -0.450202
# 408          136.284         125.130271  11.153729
# 73           121.762         122.863874  -1.101874
#
# [301 rows x 3 columns]

# %%
df2.describe()
# Out:
#        Actual Answers  Predicted Answers  Difference Percentage    Residual
# count      301.000000         301.000000             301.000000  301.000000
# mean       124.769904         125.206656               0.493601   -0.436753
# std          6.528046           4.665465               3.875047    4.792791
# min        107.147000         109.050989              -9.101263  -15.466192
# 25%        120.657000         122.624086              -2.052051   -3.286913
# 50%        125.499000         125.331553               0.144294   -0.177922
# 75%        129.965000         128.406594               2.688985    2.700955
# max        138.758000         135.669497              13.820082   12.458355

# %%
import pickle

# Suppose your trained model variable is named `model`
with open('linear_model.pkl', 'wb') as f:
    pickle.dump(model, f)

print("Model saved successfully as 'linear_model.pkl'")
# Out:
# Model saved successfully as 'linear_model.pkl'
